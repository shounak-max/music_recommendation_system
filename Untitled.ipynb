# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("songdata.csv")
df.head(3)
# Out:
#   artist                   song                                        link  \
# 0   ABBA  Ahe's My Kind Of Girl  /a/abba/ahes+my+kind+of+girl_20598417.html
# 1   ABBA       Andante, Andante       /a/abba/andante+andante_20002708.html
# 2   ABBA         As Good As New        /a/abba/as+good+as+new_20003033.html
#
#                                                 text
# 0  Look at her face, it's a wonderful face  \nAnd...
# 1  Take it easy with me, please  \nTouch me gentl...
# 2  I'll never know why I had to go  \nWhy I had t...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df.sample(n=5000).drop('link',axis=1).reset_index(drop=True)
# Out:
#                         artist                           song  \
# 0                Lenny Kravitz                I'll Be Waiting
# 1     Electric Light Orchestra                        So Fine
# 2               Violent Femmes                    I'm Nothing
# 3                Stevie Wonder                     Cold Chill
# 4                         Rush                    Vapor Trail
# ...                        ...                            ...
# 4995              Phil Collins             Oughta Know By Now
# 4996              Kenny Rogers  Some Prisons Don't Have Walls
# 4997              Neil Diamond             Don't Make Me Over
# 4998               John Legend                          Bliss
# 4999            Lynyrd Skynyrd                Georgia Peaches
#
#                                                    text
# 0     He broke your heart  \nHe took your soul  \nYo...
# 1     Two drifters on the morning sky,  \nTwo drifte...
# ...

# %%
df.shape
# Out:
# (57650, 4)

# %%
df['artist']
# Out:
# 0                ABBA
# 1                ABBA
# 2                ABBA
# 3                ABBA
# 4                ABBA
#              ...
# 57645    Ziggy Marley
# 57646    Ziggy Marley
# 57647            Zwan
# 57648            Zwan
# 57649            Zwan
# Name: artist, Length: 57650, dtype: object

# %%
df['song']
# Out:
# 0        Ahe's My Kind Of Girl
# 1             Andante, Andante
# 2               As Good As New
# 3                         Bang
# 4             Bang-A-Boomerang
#                  ...
# 57645            Good Old Days
# 57646            Hand To Mouth
# 57647             Come With Me
# 57648                   Desire
# 57649                Heartsong
# Name: song, Length: 57650, dtype: object

# %%
df['text'][0]
# Out:
# "Look at her face, it's a wonderful face  \nAnd it means something special to me  \nLook at the way that she smiles when she sees me  \nHow lucky can one fellow be?  \n  \nShe's just my kind of girl, she makes me feel fine  \nWho could ever believe that she could be mine?  \nShe's just my kind of girl, without her I'm blue  \nAnd if she ever leaves me what could I do, what could I do?  \n  \nAnd when we go for a walk in the park  \nAnd she holds me and squeezes my hand  \nWe'll go on walking for hours and talking  \nAbout all the things that we plan  \n  \nShe's just my kind of girl, she makes me feel fine  \nWho could ever believe that she could be mine?  \nShe's just my kind of girl, without her I'm blue  \nAnd if she ever leaves me what could I do, what could I do?\n\n"

# %%
df['text'].str.lower().replace([r'[^\W\S]','']).replace('\\n',' ',regex=True)
# Out:
# C:\Users\shoun\AppData\Local\Temp\ipykernel_2012\2236359146.py:1: FutureWarning: Series.replace without 'value' and with non-dict-like 'to_replace' is deprecated and will raise in a future version. Explicitly specify the new values instead.
#   df['text'].str.lower().replace([r'[^\W\S]','']).replace('\\n')
# 0        look at her face, it's a wonderful face  \nand...
# 1        take it easy with me, please  \ntouch me gentl...
# 2        i'll never know why i had to go  \nwhy i had t...
# 3        making somebody happy is a question of give an...
# 4        making somebody happy is a question of give an...
#                                ...
# 57645    irie days come on play  \nlet the angels fly l...
# 57646    power to the workers  \nmore power  \npower to...
# 57647    all you need  \nis something i'll believe  \nf...
# 57648    northern star  \nam i frightened  \nwhere can ...
# 57649    come in  \nmake yourself at home  \ni'm a bit ...
# Name: text, Length: 57650, dtype: object
